# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
from tuning import Tuning

# %%
event_file = '/mnt/dm11/bmi/nidq/bmi_20201006_g3_postbmi0/bmi_20201006_g3_t0_data.mat'
ptb_file = '/mnt/data/ptb/ptb_20201006_163023.mat'
spike_file = '/opt/localuser/test/1006_2020/post_bmi/spktag/model.pd'
t = Tuning()
t.load_event(event_file)
t.load_ptb(ptb_file)
t.load_spike(spike_file)
t.plot()
# Out:
# r-squared: 0.9999999999999978

# %%
event_file = '/mnt/dm11/bmi/nidq/bmi_20200219_g2_postbmi/bmi_20200219_g2_t0_data.mat'
ptb_file = '/mnt/data/ptb/ptb_20200219_164007.mat'
spike_file = '/mnt/data/bmi_20200219/BMI_post/spktag/post_bmi.pd'
t = Tuning()
t.load_event(event_file)
t.load_ptb(ptb_file)
t.load_spike(spike_file)
t.plot()
# Out:
# r-squared: 0.983102571562439

# %%
event_file = '/mnt/dm11/bmi/nidq/bmi_20200219_g2_postbmi/bmi_20200219_g2_t0_data.mat'
ptb_file = '/mnt/data/ptb/ptb_20200219_164007.mat'
spike_file = '/mnt/data/bmi_20200219/BMI_post/spktag/post_bmi.pd'

t = Tuning()
t.load_event(event_file)
t.load_ptb(ptb_file)
t.load_spike(spike_file)
t.plot()
# Out:
# r-squared: 0.983102571562439
